# %% [markdown]
# **APMA 940: Mathematics of Data Science**
# Project: *Association Rule Learning with Applications to Market Basket Analysis*
# Author: Javier Almonacid
# Date: April 12, 2023
#
# ---

# %% [markdown]
# # MBA Example 1: Supermarket Data Set
#
# We run first a more academic example in which the data set is not too large and is already formatted as a binary matrix. The data set, which originates from point-of-sale transactions in a small supermarket, contains 1361 transactions (rows) and 255 items (columns).
#
# >Data Set Source: M. Barksy. CSCI 485: Data Mining 2012, Lab 7. Department of Computer Science, Vancouver Island University (2012). Available at [http://csci.viu.ca/~barskym/teaching/DM2012/labs/LAB7/PartII.html](http://csci.viu.ca/~barskym/teaching/DM2012/labs/LAB7/PartII.html). Accessed on April 12, 2023.

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

pd.set_option('display.max_columns', 75)

basket_encoded = pd.read_csv("marketbasket_viu.csv")
print("Number of rows: "+str(len(basket_encoded.index)))
# Out:
# Number of rows: 1361

# %% [markdown]
# ## Preprocessing
#
# We now have only two preprocessing tasks to perform. First, because an association rule requires at least two items, we have to remove from the database all single-item transactions. Then, we convert the numeric entries (0 and 1) into boolean ones (False and True, respectively).

# %%
# Keep only those rows where more than one item was purchased.
basket_filtered = basket_encoded[(basket_encoded > 0).sum(axis=1) >= 2]

# Convert numeric entries into boolean type.
basket_filtered = basket_filtered.applymap(bool)

print("Number of rows after cleaning: "+str(len(basket_filtered.index)))
basket_filtered
# Out:
# Number of rows after cleaning: 611
#        Hair Conditioner   Lemons   Standard coffee   Frozen Chicken Wings  \
# 1                 False    False             False                  False
# 7                 False    False             False                  False
# 10                False    False             False                  False
# 11                False    False             False                  False
# 12                False    False             False                  False
# ...                 ...      ...               ...                    ...
# 1350              False    False             False                  False
# 1356              False    False             False                  False
# 1358              False    False             False                   True
# 1359               True    False             False                  False
# 1360              False    False             False                  False
#
#        98pct. Fat Free Hamburger   Sugar Cookies   Onions   Deli Ham  \
# 1                          False           False    False      False
# 7                           True           False    False      False
# 10                         False           False    False      False
# 11                         False           False    False      False
# 12                         False            True     True      False
# ...                          ...             ...      ...        ...
# 1350                       False           False    False      False
# 1356                       False           False    False      False
# 1358                        True            True     True      False
# 1359                        True            True    False      False
# 1360                        True           False    False      False
#
#        Dishwasher Detergent   Beets   40 Watt Lightbulb   Ice Cream  \
# 1                     False   False               False       False
# 7                     False   False               False       False
# 10                    False   False               False       False
# 11                    False   False               False       False
# 12                    False   False               False        True
# ...                     ...     ...                 ...         ...
# 1350                  False   False               False       False
# 1356                  False   False               False       False
# 1358                  False   False                True       False
# 1359                  False   False               False        True
# 1360                  False   False               False       False
#
#        Cottage Cheese   Plain English Muffins   Strawberry Soda  \
# 1               False                   False             False
# 7               False                   False             False
# 10              False                   False             False
# 11              False                   False             False
# 12              False                   False             False
# ...               ...                     ...               ...
# 1350            False                   False             False
# 1356            False                   False             False
# 1358            False                   False             False
# 1359            False                   False             False
# 1360            False                   False             False
#
#        Vanilla Ice Cream   Potato Chips   Strawberry Yogurt   Diet Soda  \
# 1                  False          False               False       False
# 7                  False           True               False       False
# 10                 False          False               False       False
# 11                 False          False               False       False
# 12                 False          False               False       False
# ...                  ...            ...                 ...         ...
# 1350               False          False               False       False
# 1356               False          False               False       False
# 1358               False           True               False       False
# 1359               False          False               False       False
# 1360               False          False               False       False
#
#        D Cell Batteries   Paper Towels   Mint Chocolate Bar   Salsa Dip  \
# 1                 False          False                False       False
# 7                 False          False                False       False
# 10                False          False                False       False
# 11                False          False                False       False
# 12                False          False                False       False
# ...                 ...            ...                  ...         ...
# 1350              False          False                False       False
# 1356              False          False                False       False
# 1358              False          False                 True       False
# 1359              False           True                False        True
# 1360              False          False                False       False
#
#        Buttered Popcorn   Cheese Crackers   Chocolate Bar   Rice Soup  \
# 1                 False             False           False       False
# 7                 False             False           False       False
# 10                False             False           False       False
# 11                False             False           False       False
# 12                False             False           False       False
# ...                 ...               ...             ...         ...
# 1350              False             False           False       False
# 1356              False             False           False       False
# 1358               True              True           False       False
# 1359              False             False           False       False
# 1360              False             False           False       False
#
#        Mouthwash   Sugar   Cheese Flavored Chips   Sweat Potatoes   Deodorant  \
# 1          False   False                   False            False       False
# 7          False   False                   False            False       False
# 10         False   False                   False            False       False
# 11         False   False                   False            False       False
# 12         False   False                   False            False       False
# ...          ...     ...                     ...              ...         ...
# 1350       False   False                   False            False       False
# 1356       False   False                   False            False       False
# 1358        True   False                   False            False       False
# 1359       False   False                   False            False       False
# 1360       False   False                   False            False       False
#
#        Waffles   Decaf Coffee   Smoked Turkey Sliced   Screw Driver  \
# 1        False          False                  False          False
# 7        False          False                  False          False
# 10       False          False                  False          False
# 11       False          False                  False          False
# 12       False          False                  False          False
# ...        ...            ...                    ...            ...
# 1350     False          False                  False          False
# 1356     False          False                  False          False
# 1358     False          False                  False           True
# 1359      True          False                  False           True
# 1360     False          False                  False          False
#
#        Sesame Oil  ...   Mixed Nuts   Chicken TV Dinner   Tissues   Garlic  \
# 1           False  ...        False               False     False    False
# 7            True  ...        False               False     False    False
# 10          False  ...        False               False     False    False
# 11          False  ...        False               False     False    False
# 12          False  ...        False               False     False    False
# ...           ...  ...          ...                 ...       ...      ...
# 1350        False  ...        False               False     False    False
# 1356        False  ...        False               False     False    False
# 1358        False  ...        False               False     False     True
# 1359        False  ...        False               False     False    False
# 1360        False  ...        False                True     False    False
#
#        Dried Fruit Mix   Cole Slaw   Donuts   Sliced Turkey   Sliced Chicken  \
# 1                False       False    False           False            False
# 7                False       False    False           False            False
# 10               False       False    False           False            False
# 11               False       False    False           False            False
# 12               False       False    False           False            False
# ...                ...         ...      ...             ...              ...
# 1350             False       False    False           False            False
# 1356             False       False    False           False            False
# 1358              True       False    False           False             True
# 1359             False        True     True           False            False
# 1360             False       False    False           False            False
#
#        Broccoli   Ranch Dip   Sponge   Frozen Corn   Paper Cups   Wheat Bread  \
# 1         False       False    False          True        False         False
# 7         False       False    False         False        False         False
# 10        False       False    False         False        False         False
# 11        False       False    False         False        False         False
# 12        False       False    False         False        False         False
# ...         ...         ...      ...           ...          ...           ...
# 1350      False       False    False         False        False         False
# 1356      False       False    False         False        False         False
# 1358      False       False     True         False        False          True
# 1359      False       False    False         False        False         False
# 1360      False       False    False         False        False         False
#
#        Oven Cleaner   Tomato Sauce   Plastic Forks   Popcorn  \
# 1             False          False           False     False
# 7             False          False           False     False
# 10            False          False           False     False
# 11            False          False           False     False
# 12            False          False           False     False
# ...             ...            ...             ...       ...
# 1350          False          False           False     False
# 1356          False          False           False     False
# 1358           True           True           False     False
# 1359           True          False            True     False
# 1360          False          False           False     False
#
#        Creamy Peanut Butter   Sweet Relish   Plain Muffins   Cheese Dip  \
# 1                     False          False           False        False
# 7                     False          False           False        False
# 10                    False          False           False        False
# 11                    False          False           False        False
# 12                    False          False           False        False
# ...                     ...            ...             ...          ...
# 1350                  False          False           False        False
# 1356                  False          False           False        False
# 1358                  False          False           False        False
# 1359                  False          False           False         True
# 1360                  False           True           False        False
#
#        Colby Cheese   Chicken Noodle Soup   Fingernail Clippers   Corned Beef  \
# 1             False                 False                 False         False
# 7             False                 False                 False         False
# 10            False                 False                 False         False
# 11            False                 False                 False         False
# 12            False                  True                 False         False
# ...             ...                   ...                   ...           ...
# 1350          False                 False                 False         False
# 1356          False                 False                 False         False
# 1358          False                  True                 False         False
# 1359           True                 False                 False         False
# 1360          False                 False                 False         False
#
#        Lollipops   Plain White Bread   Blueberry Yogurt  \
# 1          False               False              False
# 7           True               False              False
# 10         False               False              False
# 11         False               False              False
# 12         False               False              False
# ...          ...                 ...                ...
# 1350       False               False              False
# 1356       False               False              False
# 1358        True               False              False
# 1359       False               False              False
# 1360       False               False              False
#
#        Frozen Chicken Thighs   Mixed Vegetables   Souring Pads   Tuna Spread  \
# 1                      False              False          False         False
# 7                      False              False          False         False
# 10                     False              False          False         False
# 11                     False              False          False         False
# 12                     False              False          False         False
# ...                      ...                ...            ...           ...
# 1350                   False              False           True         False
# 1356                   False              False          False         False
# 1358                   False              False          False         False
# 1359                    True              False           True         False
# 1360                   False              False          False         False
#
#        Toilet Paper   White Wine   Columbian Coffee
# 1             False        False              False
# 7             False        False              False
# 10            False        False              False
# 11            False        False              False
# 12            False        False              False
# ...             ...          ...                ...
# 1350          False        False              False
# 1356          False         True              False
# 1358          False        False              False
# 1359           True        False              False
# 1360          False        False              False
#
# [611 rows x 255 columns]

# %% [markdown]
# ## Frequent Itemset Mining
#
# The data now is in the appropriate format. First, we generate frequent itemsets with support of at least 0.04 using the Apriori algorithm.

# %%
#Generate the frequent itemsets
frequent_itemsets = apriori(basket_filtered, min_support=0.04, use_colnames=True)\
                    .sort_values("support",ascending=False).reset_index(drop=True)
print("Frequent itemsets found: "+str(len(frequent_itemsets.index))+"\n")
frequent_itemsets
# Out:
# Frequent itemsets found: 1647
#        support                                           itemsets
# 0     0.252046                                            ( Eggs)
# 1     0.243863                                     ( White Bread)
# 2     0.219313                                      ( 2pct. Milk)
# 3     0.201309                                    ( Potato Chips)
# 4     0.201309                       ( 98pct. Fat Free Hamburger)
# ...        ...                                                ...
# 1642  0.040917               ( White Bread,  Jelly Filled Donuts)
# 1643  0.040917                      ( French Fries,  Canned Tuna)
# 1644  0.040917                ( White Bread,  Cola,  Pancake Mix)
# 1645  0.040917                     ( Domestic Beer,  Canned Tuna)
# 1646  0.040917  ( White Bread,  Toothpaste,  2pct. Milk,  Whea...
#
# [1647 rows x 2 columns]

# %% [markdown]
# ## Creating the Association Rules
#
# Then, we generate association rules that have a confidence value over 0.9. We also sort the output according to their lift values.

# %%
#Apply association rules
assoc_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.9)\
             .sort_values("lift",ascending=False).reset_index(drop=True)
print("Rules found: "+str(len(assoc_rules.index)))
assoc_rules
# Out:
# Rules found: 20
#                                           antecedents     consequents  \
# 0              ( White Bread,  Wheat Bread,  Bananas)   ( 2pct. Milk)
# 1                     ( Potato Chips,  Apples,  Eggs)   ( 2pct. Milk)
# 2     ( Pepperoni Pizza - Frozen,  Eggs,  Toothpaste)   ( 2pct. Milk)
# 3   ( White Bread,  Potato Chips,  Eggs,  Toothpaste)   ( 2pct. Milk)
# 4    ( White Bread,  Eggs,  Toothpaste,  Wheat Bread)   ( 2pct. Milk)
# 5                       ( Cola,  Popcorn Salt,  Eggs)   ( 2pct. Milk)
# 6                 ( Eggs,  Popcorn Salt,  Toothpaste)   ( 2pct. Milk)
# 7          ( Potato Chips,  Toothpaste,  Wheat Bread)   ( 2pct. Milk)
# 8                ( 2pct. Milk,  Toothpaste,  Bananas)  ( White Bread)
# 9   ( Potato Chips,  Wheat Bread,  98pct. Fat Free...  ( White Bread)
# 10              ( 2pct. Milk,  Toothpaste,  Hot Dogs)  ( White Bread)
# 11                 ( Tomatoes,  Eggs,  Sugar Cookies)  ( White Bread)
# 12  ( Wheat Bread,  Eggs,  98pct. Fat Free Hamburger)  ( White Bread)
# 13              ( Wheat Bread,  2pct. Milk,  Bananas)  ( White Bread)
# 14                     ( Sweet Relish,  Plain Bagels)         ( Eggs)
# 15           ( Tomatoes,  2pct. Milk,  Sugar Cookies)         ( Eggs)
# 16            ( Potato Chips,  2pct. Milk,  Tomatoes)         ( Eggs)
# 17          ( White Bread,  Tomatoes,  Sugar Cookies)         ( Eggs)
# 18          ( Popcorn Salt,  Toothpaste,  2pct. Milk)         ( Eggs)
# 19         ( White Bread,  2pct. Milk,  Popcorn Salt)         ( Eggs)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.045827            0.219313  0.044190    0.964286  4.396855
# 1             0.044190            0.219313  0.042553    0.962963  4.390824
# 2             0.042553            0.219313  0.040917    0.961538  4.384328
# 3             0.047463            0.219313  0.044190    0.931034  4.245239
# 4             0.044190            0.219313  0.040917    0.925926  4.221946
# 5             0.044190            0.219313  0.040917    0.925926  4.221946
# 6             0.049100            0.219313  0.044190    0.900000  4.103731
# 7             0.049100            0.219313  0.044190    0.900000  4.103731
# 8             0.044190            0.243863  0.042553    0.962963  3.948794
# 9             0.047463            0.243863  0.044190    0.931034  3.817866
# 10            0.044190            0.243863  0.040917    0.925926  3.796918
# 11            0.052373            0.243863  0.047463    0.906250  3.716233
# 12            0.049100            0.243863  0.044190    0.900000  3.690604
# 13            0.049100            0.243863  0.044190    0.900000  3.690604
# 14            0.044190            0.252046  0.040917    0.925926  3.673641
# 15            0.044190            0.252046  0.040917    0.925926  3.673641
# 16            0.044190            0.252046  0.040917    0.925926  3.673641
# 17            0.052373            0.252046  0.047463    0.906250  3.595576
# 18            0.049100            0.252046  0.044190    0.900000  3.570779
# 19            0.049100            0.252046  0.044190    0.900000  3.570779
#
#     leverage  conviction  zhangs_metric
# 0   0.034140   21.859247       0.809669
# 1   0.032862   21.078560       0.807956
# 2   0.031584   20.297872       0.806222
# 3   0.033781   11.319967       0.802533
# 4   0.031225   10.539280       0.798425
# 5   0.031225   10.539280       0.798425
# 6   0.033422    7.806874       0.795372
# 7   0.033422    7.806874       0.795372
# 8   0.031777   20.415712       0.781283
# 9   0.032615   10.963993       0.774850
# 10  0.030140   10.207856       0.770685
# 11  0.034691    8.065466       0.771306
# 12  0.032216    7.561375       0.766686
# 13  0.032216    7.561375       0.766686
# 14  0.029779   10.097381       0.761438
# 15  0.029779   10.097381       0.761438
# 16  0.029779   10.097381       0.761438
# 17  0.034263    7.978178       0.761777
# 18  0.031814    7.479542       0.757124
# 19  0.031814    7.479542       0.757124

# %%
# print(assoc_rules[["antecedents",
#                    "consequents",
#                    "antecedent support",
#                    "consequent support",
#                    "support",
#                    "confidence",
#                    "lift",
#                    "conviction"]].head(20).to_latex())
